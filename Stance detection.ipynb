# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup

path = "/Users/tobiasjennert/uni/semester6/DIS25/BundestagStanceDetection/Plenarprotokolle_Wahlperiode_19/"
file = "19008-data.xml"

xml_data = open(path+file, 'r').read()  # Read file
soup = BeautifulSoup(xml_data ,'xml')

combinend_tgsordpkt = []
combinend_speaker = []
combinend_party = []
combinend_speech = []

# get the date of the Plenarsitzung
date = [soup.find("datum").attrs["date"]]

print(date)

tagesordnungspunkt = soup.find_all('tagesordnungspunkt')
for punkt in tagesordnungspunkt:
    
    # ignore tagesordnungspunkt if there is no redner
    check_for_redner = len(punkt.find_all("rede")) != 0
    if check_for_redner:
        
        tgsordpkt_all_text = [] #list to store the text from the speeches joined as one string per speaker
        tgsordpkt_all_speaker = [] #list to store the text from the speeches joined as one string per speaker
        tgsordpkt_thema = []
        tgsordpkt_speaker_party = []
        thema = punkt.find('p', {"klasse": "T_fett"})
        thema_txt = thema.get_text()
        tgsordpkt_thema.append(thema_txt)
        reden = punkt.find_all('rede')
        for rede in reden:
            # extract the text from the speeches
            plain_text = []
            text = rede.find_all('p')
            ignore_tags = ["redner"]
            for txt in text:
                if txt["klasse"] in ignore_tags:
                    continue
                #print(txt.get_text())
                plain_text.append(txt.get_text())
            joined_text = ' '.join(plain_text)
            tgsordpkt_all_text.append(joined_text)

            # extract the speaker "redner" of the speech
            redner = rede.find('p', {"klasse": "redner"})
            store_redner_info = []
            for re in redner:
                store_redner_info.append(re.get_text())
            #print(store_render_info)

            
            get_speaker = store_redner_info[-1]
            tgsordpkt_all_speaker.append(get_speaker)
            
            #extract party from redner
            print(get_speaker)
            
            if "(" in get_speaker: 
                count = 0
                while True:
                    count = count+1
                    character = get_speaker[-count]
                    if character == "(":
                        tgsordpkt_speaker_party.append(get_speaker[-count:])
                        break       
            else:
                tgsordpkt_speaker_party.append('N/A')
            

        if len(tgsordpkt_thema) < len(tgsordpkt_all_speaker):
            while len(tgsordpkt_thema) < len(tgsordpkt_all_speaker):
                tgsordpkt_thema.append(tgsordpkt_thema[0])

        combinend_tgsordpkt.append(tgsordpkt_thema)
        combinend_speaker.append(tgsordpkt_all_speaker)
        combinend_speech.append(tgsordpkt_all_text)
        combinend_party.append(tgsordpkt_speaker_party)
        
 
    
combinend_tgsordpkt = [item for sublist in combinend_tgsordpkt for item in sublist]
combinend_speaker = [item for sublist in combinend_speaker for item in sublist]
combinend_speech = [item for sublist in combinend_speech for item in sublist]
combinend_party = [item for sublist in combinend_party for item in sublist]

if len(date) < len(combinend_tgsordpkt):
    while len(date) < len(combinend_tgsordpkt):
        date.append(date[0])


print(len(combinend_tgsordpkt))
print(len(combinend_speaker))
print(len(combinend_speech))
print(len(combinend_party))

# dictionary of lists 
dict = {
    'date': date ,
    'thema': combinend_tgsordpkt, 
    'speaker': combinend_speaker, 
    'party': combinend_party,
    'speech': combinend_speech
} 
    
df = pd.DataFrame(dict)
df
# Out:
# ['19.01.2018']
# Dr. Thomas de Maizière, Bundesminister des Innern:
# Dr. Eva Högl (SPD):
# :
# )
# D
# P
# S
# (
# 6
# Martin Sichert (AfD):
# :
# )
# D
# f
# A
# (
# 6
# Stephan Thomae (FDP):
# :
# )
# P
# D
# F
# (
# 6
# Ulla Jelpke (DIE LINKE):
# :
# )
# E
# K
# N
# I
# L
#
# E
# I
# D
# (
# 12
# Katrin Göring-Eckardt (BÜNDNIS 90/DIE GRÜNEN):
# :
# )
# N
# E
# N
# Ü
# R
# G
#
# E
# I
# D
# /
# 0
# 9
#
# S
# I
# N
# D
# N
# Ü
# B
# (
# 24
# Dr. Stephan Harbarth (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Burkhard Lischka (SPD):
# :
# )
# D
# P
# S
# (
# 6
# Dr. Frauke Petry (fraktionslos):
# :
# )
# s
# o
# l
# s
# n
# o
# i
# t
# k
# a
# r
# f
# (
# 15
# Stephan Mayer (Altötting) (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Roman Johannes Reusch (AfD):
# :
# )
# D
# f
# A
# (
# 6
# Nadine Schön (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Gülistan Yüksel (SPD):
# :
# )
# D
# P
# S
# (
# 6
# Matthias Seestern-Pauly (FDP):
# :
# )
# P
# D
# F
# (
# 6
# Norbert Müller (Potsdam) (DIE LINKE):
# :
# )
# E
# K
# N
# I
# L
#
# E
# I
# D
# (
# 12
#
# Marcus Weinberg (Hamburg) (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Michael Frieser (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Michael Theurer (FDP):
# :
# )
# P
# D
# F
# (
# 6
# Dr. Matthias Zimmer (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Sabine Zimmermann (Zwickau) (DIE LINKE):
# :
# )
# E
# K
# N
# I
# L
#
# E
# I
# D
# (
# 12
# Dr. Matthias Zimmer (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Dr. Matthias Bartke (SPD):
# :
# )
# D
# P
# S
# (
# 6
# Martin Sichert (AfD):
# :
# )
# D
# f
# A
# (
# 6
# Sabine Zimmermann (Zwickau) (DIE LINKE):
# :
# )
# E
# K
# N
# I
# L
#
# E
# I
# D
# (
# 12
# Markus Kurth (BÜNDNIS 90/DIE GRÜNEN):
# :
# )
# N
# E
# N
# Ü
# R
# G
#
# E
# I
# D
# /
# 0
# 9
#
# S
# I
# N
# D
# N
# Ü
# B
# (
# 24
# Dr. h. c. Albert Weiler (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Dr. Martin Rosemann (SPD):
# :
# )
# D
# P
# S
# (
# 6
# Stephan Stracke (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Tobias Pflüger (DIE LINKE):
# :
# )
# E
# K
# N
# I
# L
#
# E
# I
# D
# (
# 12
# Henning Otte (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Thomas Hitschler (SPD):
# :
# )
# D
# P
# S
# (
# 6
# Rüdiger Lucassen (AfD):
# :
# )
# D
# f
# A
# (
# 6
# Dr. Marie-Agnes Strack-Zimmermann (FDP):
# :
# )
# P
# D
# F
# (
# 6
# Dr. Tobias Lindner (BÜNDNIS 90/DIE GRÜNEN):
# :
# )
# N
# E
# N
# Ü
# R
# G
#
# E
# I
# D
# /
# 0
# 9
#
# S
# I
# N
# D
# N
# Ü
# B
# (
# 24
# Florian Hahn (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Dr. Diether Dehm (DIE LINKE):
# :
# )
# E
# K
# N
# I
# L
#
# E
# I
# D
# (
# 12
# Florian Hahn (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Wolfgang Hellmich (SPD):
# :
# )
# D
# P
# S
# (
# 6
# Dr. Dr. h. c. Karl A. Lamers (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Dr. Alexander S. Neu (DIE LINKE):
# :
# )
# E
# K
# N
# I
# L
#
# E
# I
# D
# (
# 12
# Dr. Dr. h. c. Karl A. Lamers (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Kordula Schulz-Asche (BÜNDNIS 90/DIE GRÜNEN):
# :
# )
# N
# E
# N
# Ü
# R
# G
#
# E
# I
# D
# /
# 0
# 9
#
# S
# I
# N
# D
# N
# Ü
# B
# (
# 24
# Erwin Rüddel (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Heike Baehrens (SPD):
# :
# )
# D
# P
# S
# (
# 6
# Dr. Robby Schlund (AfD):
# :
# )
# D
# f
# A
# (
# 6
# Nicole Westig (FDP):
# :
# )
# P
# D
# F
# (
# 6
# Pia Zimmermann (DIE LINKE):
# :
# )
# E
# K
# N
# I
# L
#
# E
# I
# D
# (
# 12
# Kordula Schulz-Asche (BÜNDNIS 90/DIE GRÜNEN):
# :
# )
# N
# E
# N
# Ü
# R
# G
#
# E
# I
# D
# /
# 0
# 9
#
# S
# I
# N
# D
# N
# Ü
# B
# (
# 24
# Pia Zimmermann (DIE LINKE):
# :
# )
# E
# K
# N
# I
# L
#
# E
# I
# D
# (
# 12
# Erich Irlstorfer (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# Claudia Moll (SPD):
# :
# )
# D
# P
# S
# (
# 6
# Lothar Riebsamen (CDU/CSU):
# :
# )
# U
# S
# C
# /
# U
# D
# C
# (
# 10
# 53
# 53
# 53
# 53
#           date                                              thema  \
# 0   19.01.2018  Familiennachzug auch zu subsidiär Schutzberech...
# 1   19.01.2018  Familiennachzug auch zu subsidiär Schutzberech...
# 2   19.01.2018  Familiennachzug auch zu subsidiär Schutzberech...
# 3   19.01.2018  Familiennachzug auch zu subsidiär Schutzberech...
# 4   19.01.2018  Familiennachzug auch zu subsidiär Schutzberech...
# 5   19.01.2018  Familiennachzug auch zu subsidiär Schutzberech...
# 6   19.01.2018  Familiennachzug auch zu subsidiär Schutzberech...
# 7   19.01.2018  Familiennachzug auch zu subsidiär Schutzberech...
# 8   19.01.2018  Familiennachzug auch zu subsidiär Schutzberech...
# 9   19.01.2018  Familiennachzug auch zu subsidiär Schutzberech...
# 10  19.01.2018  Obligatorische Altersfeststellung unbegleitete...
# 11  19.01.2018  Obligatorische Altersfeststellung unbegleitete...
# 12  19.01.2018  Obligatorische Altersfeststellung unbegleitete...
# 13  19.01.2018  Obligatorische Altersfeststellung unbegleitete...
# 14  19.01.2018  Obligatorische Altersfeststellung unbegleitete...
# 15  19.01.2018  Obligatorische Altersfeststellung unbegleitete...
# 16  19.01.2018  Obligatorische Altersfeststellung unbegleitete...
# 17  19.01.2018  Obligatorische Altersfeststellung unbegleitete...
# 18  19.01.2018              Kehrtwende in der Arbeitsmarktpolitik
# 19  19.01.2018              Kehrtwende in der Arbeitsmarktpolitik
# 20  19.01.2018              Kehrtwende in der Arbeitsmarktpolitik
# 21  19.01.2018              Kehrtwende in der Arbeitsmarktpolitik
# 22  19.01.2018              Kehrtwende in der Arbeitsmarktpolitik
# 23  19.01.2018              Kehrtwende in der Arbeitsmarktpolitik
# 24  19.01.2018              Kehrtwende in der Arbeitsmarktpolitik
# 25  19.01.2018              Kehrtwende in der Arbeitsmarktpolitik
# 26  19.01.2018              Kehrtwende in der Arbeitsmarktpolitik
# 27  19.01.2018              Kehrtwende in der Arbeitsmarktpolitik
# 28  19.01.2018              Kehrtwende in der Arbeitsmarktpolitik
# 29  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 30  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 31  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 32  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 33  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 34  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 35  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 36  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 37  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 38  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 39  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 40  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 41  19.01.2018        Zwei-Prozent-Rüstungsziel der NATO ablehnen
# 42  19.01.2018  Sofortprogramm für mehr Personal in der Altenp...
# 43  19.01.2018  Sofortprogramm für mehr Personal in der Altenp...
# 44  19.01.2018  Sofortprogramm für mehr Personal in der Altenp...
# 45  19.01.2018  Sofortprogramm für mehr Personal in der Altenp...
# 46  19.01.2018  Sofortprogramm für mehr Personal in der Altenp...
# 47  19.01.2018  Sofortprogramm für mehr Personal in der Altenp...
# 48  19.01.2018  Sofortprogramm für mehr Personal in der Altenp...
# 49  19.01.2018  Sofortprogramm für mehr Personal in der Altenp...
# 50  19.01.2018  Sofortprogramm für mehr Personal in der Altenp...
# 51  19.01.2018  Sofortprogramm für mehr Personal in der Altenp...
# 52  19.01.2018  Sofortprogramm für mehr Personal in der Altenp...
#
#                                               speaker  \
# 0   Dr. Thomas de Maizière, Bundesminister des Inn...
# 1                                 Dr. Eva Högl (SPD):
# 2                               Martin Sichert (AfD):
# 3                               Stephan Thomae (FDP):
# 4                            Ulla Jelpke (DIE LINKE):
# 5      Katrin Göring-Eckardt (BÜNDNIS 90/DIE GRÜNEN):
# 6                     Dr. Stephan Harbarth (CDU/CSU):
# 7                             Burkhard Lischka (SPD):
# 8                    Dr. Frauke Petry (fraktionslos):
# 9                Stephan Mayer (Altötting) (CDU/CSU):
# 10                       Roman Johannes Reusch (AfD):
# 11                            Nadine Schön (CDU/CSU):
# 12                             Gülistan Yüksel (SPD):
# 13                     Matthias Seestern-Pauly (FDP):
# 14              Norbert Müller (Potsdam) (DIE LINKE):
# 15
# 16               Marcus Weinberg (Hamburg) (CDU/CSU):
# 17                         Michael Frieser (CDU/CSU):
# 18                             Michael Theurer (FDP):
# 19                     Dr. Matthias Zimmer (CDU/CSU):
# 20           Sabine Zimmermann (Zwickau) (DIE LINKE):
# 21                     Dr. Matthias Zimmer (CDU/CSU):
# 22                         Dr. Matthias Bartke (SPD):
# 23                              Martin Sichert (AfD):
# 24           Sabine Zimmermann (Zwickau) (DIE LINKE):
# 25              Markus Kurth (BÜNDNIS 90/DIE GRÜNEN):
# 26                 Dr. h. c. Albert Weiler (CDU/CSU):
# 27                         Dr. Martin Rosemann (SPD):
# 28                         Stephan Stracke (CDU/CSU):
# 29                        Tobias Pflüger (DIE LINKE):
# 30                            Henning Otte (CDU/CSU):
# 31                            Thomas Hitschler (SPD):
# 32                            Rüdiger Lucassen (AfD):
# 33           Dr. Marie-Agnes Strack-Zimmermann (FDP):
# 34        Dr. Tobias Lindner (BÜNDNIS 90/DIE GRÜNEN):
# 35                            Florian Hahn (CDU/CSU):
# 36                      Dr. Diether Dehm (DIE LINKE):
# 37                            Florian Hahn (CDU/CSU):
# 38                           Wolfgang Hellmich (SPD):
# 39            Dr. Dr. h. c. Karl A. Lamers (CDU/CSU):
# 40                  Dr. Alexander S. Neu (DIE LINKE):
# 41            Dr. Dr. h. c. Karl A. Lamers (CDU/CSU):
# 42      Kordula Schulz-Asche (BÜNDNIS 90/DIE GRÜNEN):
# 43                            Erwin Rüddel (CDU/CSU):
# 44                              Heike Baehrens (SPD):
# 45                           Dr. Robby Schlund (AfD):
# 46                               Nicole Westig (FDP):
# 47                        Pia Zimmermann (DIE LINKE):
# 48      Kordula Schulz-Asche (BÜNDNIS 90/DIE GRÜNEN):
# 49                        Pia Zimmermann (DIE LINKE):
# 50                        Erich Irlstorfer (CDU/CSU):
# 51                                Claudia Moll (SPD):
# 52                        Lothar Riebsamen (CDU/CSU):
#
#                        party  \
# 0                        N/A
# 1                     (SPD):
# 2                     (AfD):
# 3                     (FDP):
# 4               (DIE LINKE):
# 5   (BÜNDNIS 90/DIE GRÜNEN):
# 6                 (CDU/CSU):
# 7                     (SPD):
# 8            (fraktionslos):
# 9                 (CDU/CSU):
# 10                    (AfD):
# 11                (CDU/CSU):
# 12                    (SPD):
# 13                    (FDP):
# 14              (DIE LINKE):
# 15                       N/A
# 16                (CDU/CSU):
# 17                (CDU/CSU):
# 18                    (FDP):
# 19                (CDU/CSU):
# 20              (DIE LINKE):
# 21                (CDU/CSU):
# 22                    (SPD):
# 23                    (AfD):
# 24              (DIE LINKE):
# 25  (BÜNDNIS 90/DIE GRÜNEN):
# 26                (CDU/CSU):
# 27                    (SPD):
# 28                (CDU/CSU):
# 29              (DIE LINKE):
# 30                (CDU/CSU):
# 31                    (SPD):
# 32                    (AfD):
# 33                    (FDP):
# 34  (BÜNDNIS 90/DIE GRÜNEN):
# 35                (CDU/CSU):
# 36              (DIE LINKE):
# 37                (CDU/CSU):
# 38                    (SPD):
# 39                (CDU/CSU):
# 40              (DIE LINKE):
# 41                (CDU/CSU):
# 42  (BÜNDNIS 90/DIE GRÜNEN):
# 43                (CDU/CSU):
# 44                    (SPD):
# 45                    (AfD):
# 46                    (FDP):
# 47              (DIE LINKE):
# 48  (BÜNDNIS 90/DIE GRÜNEN):
# 49              (DIE LINKE):
# 50                (CDU/CSU):
# 51                    (SPD):
# 52                (CDU/CSU):
#
#                                                speech
# 0   Herr Präsident! Liebe Kolleginnen und Kollegen...
# 1   Einen schönen guten Morgen, sehr geehrter Herr...
# 2   Herr Präsident! Meine Damen und Herren! Die As...
# 3   Herr Präsident! Verehrte Kolleginnen und Kolle...
# 4   Herr Präsident! Meine Damen und Herren! Herr d...
# 5   Herr Präsident! Liebe Kolleginnen und Kollegen...
# 6   Herr Präsident! Verehrte Kolleginnen und Kolle...
# 7   Herr Präsident! Meine Damen und Herren! Vor gu...
# 8   Sehr geehrter Herr Präsident! Meine sehr geehr...
# 9   Sehr geehrter Herr Präsident! Sehr verehrte Ko...
# 10  Herr Präsident! Meine Damen und Herren! Nicht ...
# 11  Sehr geehrter Herr Präsident! Liebe Kolleginne...
# 12  Sehr geehrter Herr Präsident! Sehr geehrte Dam...
# 13  Sehr geehrter Herr Präsident! Meine sehr geehr...
# 14  Guten Morgen, sehr geehrter Herr Präsident! Me...
# 15  Sehr geehrter Herr Präsident! Liebe Kolleginne...
# 16  Vielen Dank, Herr Präsident. – Werte Kolleginn...
# 17  Vielen Dank, Herr Präsident. – Meine werten Ko...
# 18  Sehr geehrter Herr Präsident! Liebe Kolleginne...
# 19  Herr Präsident! Meine Damen und Herren! Wir be...
# 20  Danke schön, Herr Präsident. – Ich will nur ku...
# 21  Ich will es ganz kurz machen. – Ich finde es b...
# 22  Herr Präsident! Meine Damen und Herren! In der...
# 23  Herr Präsident! Meine Damen und Herren! Wenn m...
# 24  Sehr geehrter Herr Präsident! Meine Damen und ...
# 25  Herr Präsident! Verehrte Kolleginnen und Kolle...
# 26  Sehr geehrter Herr Präsident! Verehrte Damen u...
# 27  Herr Präsident! Meine sehr geehrten Damen und ...
# 28  Sehr geehrter Herr Präsident! Meine sehr vereh...
# 29  Herr Präsident! Liebe Kolleginnen und Kollegen...
# 30  Herr Präsident! Meine sehr verehrten Damen und...
# 31  Sehr geehrter Herr Präsident! Liebe Kolleginne...
# 32  Herr Präsident! Sehr geehrte Abgeordnete! Der ...
# 33  Sehr geehrter Herr Präsident! Meine sehr vereh...
# 34  Herr Präsident! Liebe Kolleginnen und Kollegen...
# 35  Sehr geehrter Herr Präsident! Liebe Kolleginne...
# 36  Herr Kollege, es wäre besser gewesen, wir hätt...
# 37  Herr Kollege Dehm, mit Blick auf die Ausgaben ...
# 38  Herr Präsident! Liebe Kolleginnen und Kollegen...
# 39  Herr Präsident! Liebe Kolleginnen und Kollegen...
# 40  Vielen Dank. – Es scheint bei der CDU/CSU eine...
# 41  Ich möchte sehr gerne antworten. Herr Kollege ...
# 42  Herr Präsident! Meine Damen und Herren! Seit l...
# 43  Sehr geehrter Herr Präsident! Meine Damen und ...
# 44  Herr Präsident! Sehr geehrte Damen und Herren!...
# 45  Herr Präsident! Sehr geehrte Kollegen! Liebe G...
# 46  Herr Präsident! Meine Damen und Herren! Die FD...
# 47  Vielen Dank. – Herr Präsident! Meine Damen und...
# 48  Frau Kollegin Zimmermann, wir saßen in der let...
# 49  Vielen Dank für die Nachfrage. – Zum ersten Pu...
# 50  Sehr geehrter Herr Präsident! Werte Kolleginne...
# 51  Danke schön. – Sehr geehrter Herr Präsident! L...
# 52  Sehr geehrter Herr Präsident! Verehrte Kollegi...

# %%
#import sys
#!/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install textblob
#!python3 -m textblob.download_corpora
#from textblob_de import TextBlobDE as TextBlob
#!pip install textblob_de
#!pip install --user -U nltk
#!/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install spacy
#!/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip setuptools wheel
#!pip install spacy-sentiws
#import spacy
#!/Library/Developer/CommandLineTools/usr/bin/python3 -m spacy download de_core_news_sm

# %% [markdown]
# # TextBlob (German)

# %%
from textblob_de import TextBlobDE as TextBlob
from pandarallel import pandarallel  # parallelization
pandarallel.initialize()

def get_polarity(input_speech):
    speech = TextBlob(input_speech)
    return speech.sentiment.polarity

df["polarity_textblob"] = df.parallel_apply(lambda row: get_polarity(row["speech"]), axis=1)
df

# %% [markdown]
# # VADER

# %%
#translate text to english because vader is only working properly in english language
from deep_translator import GoogleTranslator

#translate text to english language
def translate_en(text):
    translated = GoogleTranslator(source='auto', target='en').translate(text)
    return translated


def translate_speech(text):
    #split text after 4999 characaters, translate both path separatly and join them afterwards
    if len(text) > 5000: 
        cut_text= text[:4999]
        for idx, c in enumerate(reversed(cut_text)):
            #print(idx, c)
            if c == " ":
                print(idx, c)
                first_part = text[:4999 - idx]
                first_part_trans = translate_en(first_part)
                second_part = text[len(first_part):]
                second_part_trans = translate_en(second_part)
                combined_text = first_part_trans + " " + second_part_trans
                print(combined_text)
                return combined_text
    return translate_en(text)

# PROBLEM: translation is limited TO 5000 characters!!!
df["translated_speech"] = df.apply(lambda row: translate_speech(row["speech"]), axis=1)
df

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

def get_polarity_vader(input_speech):
    sid_obj = SentimentIntensityAnalyzer()
    sentiment_dict = sid_obj.polarity_scores(input_speech)
    return sentiment_dict["compound"]
    
df["polarity_vader"] = df.apply(lambda row: get_polarity_vader(row["translated_speech"][:4999]), axis=1)
df
